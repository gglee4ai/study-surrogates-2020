# %%
if (getwd() == "/") setwd("/root")

# %%
lgbb1 <- read.table("data/lgbb/lgbb_original.txt", header=TRUE)
lgbb1
# Out:
#      mach alpha beta lift     drag    pitch    side     yaw      roll
# 1    0.2  -5    0    -0.09536 0.00060 -0.02869  0.00076 -0.00032  0.00010
# 2    0.2  -2    0     0.05032 0.02859 -0.03162  0.00139 -0.00045  0.00016
# 3    0.2   0    0     0.15801 0.05241 -0.03772  0.00122 -0.00060  0.00015
# 4    0.2   1    0     0.20419 0.05498 -0.03833  0.00131 -0.00057  0.00018
# 5    0.2   2    0     0.24364 0.05744 -0.03822  0.00125 -0.00062  0.00015
# 6    0.2   5    0     0.37647 0.07342 -0.03992  0.00146 -0.00031  0.00009
# 7    0.2   8    0     0.51565 0.09798 -0.04179  0.00099 -0.00055  0.00014
# 8    0.2  10    0     0.60841 0.12075 -0.04245  0.00090 -0.00025 -0.00002
# 9    0.2  12    0     0.69804 0.15149 -0.04354  0.00044 -0.00027 -0.00002
# 10   0.2  15    0     0.83049 0.20591 -0.04567  0.00087 -0.00032  0.00005
# 11   0.2  16    0     0.87609 0.22712 -0.04524  0.00044 -0.00042 -0.00018
# 12   0.2  17    0     0.91671 0.24793 -0.04631 -0.00062 -0.00078 -0.00011
# 13   0.2  18    0     0.95803 0.27081 -0.04599  0.00080 -0.00034  0.00001
# 14   0.2  19    0     0.99969 0.29580 -0.04644  0.00139 -0.00035  0.00015
# 15   0.2  20    0     1.03901 0.32175 -0.04633  0.00109 -0.00034  0.00008
# 16   0.2  21    0     1.07716 0.34929 -0.04732  0.00057 -0.00056  0.00015
# 17   0.2  22    0     1.11984 0.37566 -0.04727  0.00019 -0.00093  0.00003
# 18   0.2  23    0     1.15105 0.41005 -0.04811  0.00048 -0.00049 -0.00011
# 19   0.2  24    0     1.19123 0.43920 -0.04830  0.00015 -0.00071  0.00001
# 20   0.2  25    0     1.22345 0.47319 -0.04867  0.00119 -0.00059  0.00004
# 21   0.2  26    0     1.26416 0.49748 -0.04980  0.00047 -0.00063  0.00009
# 22   0.2  27    0     1.29923 0.52260 -0.05084  0.00004 -0.00084  0.00008
# 23   0.2  28    0     1.32030 0.55854 -0.05246  0.00025 -0.00048  0.00016
# 24   0.2  29    0     1.33719 0.61031 -0.05362 -0.00081 -0.00051  0.00025
# 25   0.2  30    0     1.34735 0.66254 -0.05332 -0.00154 -0.00049  0.00026
# 26   0.3  -5    0    -0.09891 0.00719 -0.02743  0.00144 -0.00040  0.00015
# 27   0.3  -2    0     0.05108 0.03775 -0.03185  0.00039 -0.00035  0.00010
# 28   0.3   0    0     0.14088 0.03820 -0.03349  0.00045 -0.00036  0.00013
# 29   0.3   1    0     0.18693 0.04080 -0.03428  0.00055 -0.00031  0.00010
# 30   0.3   2    0     0.23342 0.04422 -0.03535  0.00041 -0.00036  0.00007
# ⋮    ⋮    ⋮     ⋮    ⋮        ⋮       ⋮        ⋮        ⋮        ⋮
# 3138 5.86 -5    4    -0.09940 0.05997 -0.00559 -0.04150 -0.00326  0.00127
# 3139 5.86  0    4    -0.01919 0.04660 -0.00198 -0.03673 -0.00360  0.00073
# 3140 5.86  2    4     0.01319 0.04389 -0.00080 -0.03318 -0.00357  0.00049
# 3141 5.86  5    4     0.06530 0.04781  0.00135 -0.03238 -0.00374  0.00003
# 3142 5.86  8    4     0.12379 0.05978  0.00368 -0.03052 -0.00411 -0.00056
# 3143 5.86 10    4     0.16739 0.07294  0.00516 -0.02940 -0.00461 -0.00095
# 3144 5.86 15    4     0.29224 0.12543  0.00751 -0.02714 -0.00616 -0.00136
# 3145 5.86 17    4     0.34919 0.15562  0.00787 -0.02644 -0.00691 -0.00143
# 3146 5.86 18    4     0.37855 0.17277  0.00803 -0.02595 -0.00725 -0.00146
# 3147 5.86 20    4     0.43949 0.21155  0.00797 -0.02505 -0.00784 -0.00159
# 3148 5.86 22    4     0.50248 0.25629  0.00770 -0.02427 -0.00822 -0.00200
# 3149 5.86 24    4     0.56917 0.30796  0.00684 -0.02388 -0.00852 -0.00243
# 3150 5.86 25    4     0.60266 0.33602  0.00600 -0.02375 -0.00858 -0.00262
# 3151 5.86 26    4     0.63149 0.36558  0.00476 -0.02515 -0.00854 -0.00296
# 3152 5.86 28    4     0.70655 0.43185  0.00295 -0.02188 -0.00902 -0.00287
# 3153 5.86 30    4     0.77528 0.50478  0.00076 -0.01867 -0.00934 -0.00306
# 3154 6.00 -5    4    -0.09819 0.05951 -0.00553 -0.04118 -0.00319  0.00129
# 3155 6.00  2    4     0.01343 0.04559 -0.00046 -0.03541 -0.00367  0.00047
# 3156 6.00  5    4     0.06389 0.04727  0.00145 -0.03193 -0.00369  0.00002
# 3157 6.00  8    4     0.12156 0.05923  0.00374 -0.03015 -0.00412 -0.00055
# 3158 6.00 10    4     0.16457 0.07232  0.00525 -0.02913 -0.00463 -0.00095
# 3159 6.00 12    4     0.21118 0.08969  0.00639 -0.02820 -0.00529 -0.00119
# 3160 6.00 15    4     0.28912 0.12464  0.00756 -0.02697 -0.00621 -0.00133
# 3161 6.00 20    4     0.44716 0.21745  0.00756 -0.02669 -0.00815 -0.00170
# 3162 6.00 22    4     0.49872 0.25468  0.00785 -0.02438 -0.00824 -0.00207
# 3163 6.00 24    4     0.56566 0.30614  0.00674 -0.02418 -0.00845 -0.00247
# 3164 6.00 25    4     0.59953 0.33424  0.00623 -0.02389 -0.00842 -0.00264
# 3165 6.00 26    4     0.62816 0.36364  0.00479 -0.02507 -0.00856 -0.00295
# 3166 6.00 28    4     0.70318 0.42982  0.00318 -0.02155 -0.00880 -0.00280
# 3167 6.00 30    4     0.76981 0.50130  0.00062 -0.01895 -0.00933 -0.00300

# %%
library(akima)
g <- interp(lgbb1$mach, lgbb1$alpha, lgbb1$lift, duplicate="mean")
par(pty="s")
image(g, col=heat.colors(128), xlab="mach", ylab="alpha")
points(lgbb1$mach, lgbb1$alpha, cex=0.25, pch=18)
# Out:
# Error in library(akima): there is no package called ‘akima’
# Traceback:
#
# 1. library(akima)

# %%
# plotly 예제 
# library(plotly)  # 축이 꼬여 있음
# plot_ly(x = -g$y, y = g$x, z = g$z) %>% 
#   add_surface() %>% 
#   layout(scene = list(xaxis = list(title = "y"), yaxis = list(title = "x")))

# %%
apply(lgbb1[,1:3], 2, function(x) { length(unique(x)) })
#lgbb1 %>% select(mach, alpha, beta) %>% summarize_all(~length(unique(.)))
# Out:
#  mach alpha  beta
#    37    33     6

# %%
a1b0 <- which(lgbb1$alpha == 1 & lgbb1$beta == 0)
a1bn0 <- which(lgbb1$alpha == 1 & lgbb1$beta != 0)
a1b0 <- a1b0[order(lgbb1$mach[a1b0])]
a1bn0 <- a1bn0[order(lgbb1$mach[a1bn0])]
par(pty="s")
plot(lgbb1$mach[a1b0], lgbb1$lift[a1b0], type="l", xlab="mach", ylab="lift", ylim=range(lgbb1$lift[c(a1b0, a1bn0)]), lwd=2)
lines(lgbb1$mach[a1bn0], lgbb1$lift[a1bn0], col=2, lty=2, lwd=2)
text(4, 0.3, paste("length(a1b0) =", length(a1b0)))
text(4, 0.25, paste("length(a1bn0) =", length(a1bn0)))
legend("topright", c("beta = 0", "beta != 0"), col=1:2, lty=1:2, lwd=2)
# Out:
# plot without title

# %%
# lgbb1 %>% 
#   mutate(
#     state = ifelse(alpha == 1 & beta == 0, "a1b0",
#             ifelse(alpha == 1 & beta != 0, "a1bn0", "else"))) %>% 
#   filter(state %in% c("a1b0", "a1bn0")) %>% 
#   ggplot(aes(mach, lift, color = state, linetype = state)) +
#   geom_line(alpha = .5, size = 1.2)

# %%
lgbb2 <- read.table("data/lgbb/lgbb_as.txt", header=TRUE)
lgbb2
# Out:
#     index mach alpha beta lift         drag       pitch         side
# 1    5234 4.45  3    0.5   0.04396043  0.04898051 -0.0009133920 -4.444404e-03
# 2    6364 2.45 13    0.5   0.43458428  0.15715012 -0.0092084388 -3.365631e-03
# 3   11411 3.25 20    1.0   0.58687544  0.26652431  0.0051514692 -5.100507e-03
# 4   33717 1.20 -5    4.0  -0.25720177  0.10648916  0.0066589400 -6.101650e-02
# 5   28379 3.40 21    3.0   0.60758363  0.28704337  0.0070422433 -1.653806e-02
# 6   25483 4.85 -4    3.0  -0.09087697  0.05815997 -0.0068153264 -3.059491e-02
# 7   29173 2.15 28    3.0   1.04557972  0.61246165 -0.0104523902  5.121298e-03
# 8   12647 0.70 -5    1.5  -0.13066074  0.02677501 -0.0278046823 -2.207338e-02
# 9   25110 3.75 29    2.5   0.85682262  0.53530745  0.0084822830 -1.302212e-02
# 10  14167 0.65  8    1.5   0.56976964  0.07638460 -0.0422869751 -1.370158e-02
# 11   4331 0.25 -4    0.5  -0.05856145  0.04310928 -0.0303234936 -5.933214e-03
# 12  22637 2.95  8    2.5   0.22089863  0.08553762 -0.0039818231 -2.159877e-02
# 13  21240 3.30 -4    2.5  -0.10926473  0.06641393 -0.0053047418 -2.836584e-02
# 14  21647 0.25  0    2.5   0.13752519  0.04190068 -0.0336164964 -3.149479e-02
# 15  36757 1.10 21    4.0   1.27442206  0.55903293 -0.0917358462  5.552731e-02
# 16  30582 2.40  4    3.5   0.12346244  0.07415013 -0.0078898103 -3.246238e-02
# 17   4510 3.35 -3    0.5  -0.08383118  0.06075717 -0.0048850689 -5.463833e-03
# 18   1287 6.00  5    0.0   0.06456793  0.04753139  0.0021186767  5.363328e-05
# 19  19567 1.55 18    2.0   0.85879902  0.34091241 -0.0444550365  9.526806e-03
# 20  18244 5.60  6    2.0   0.08924863  0.05251051  0.0027621454 -1.639728e-02
# 21   7758 1.95 25    0.5   1.00097201  0.52568819 -0.0180377226  1.831374e-03
# 776  3113 3.70 21    0.0   0.584440175 0.27671992  0.009277897  -5.090043e-05
# 777 34329 2.55  0    4.0  -0.008586028 0.06685422 -0.005404649  -4.233174e-02
# 778 16119 4.65 24    1.5   0.631287157 0.33737144  0.012795630  -9.410856e-03
# 779 16105 3.95 24    1.5   0.670132915 0.35399347  0.010771447  -9.038663e-03
# 780 21042 5.10 30    2.0   0.825436182 0.53729276  0.012906938  -1.042442e-02
#     yaw           roll
# 1   -5.606522e-04  1.231886e-05
# 2   -6.515294e-04 -4.521966e-04
# 3   -2.136378e-03 -1.251947e-03
# 4    5.888223e-03 -2.352320e-08
# 5   -6.271620e-03 -4.094900e-03
# 6   -3.086127e-03  5.499092e-04
# 7   -8.126100e-03 -7.433403e-03
# 8    1.548839e-03 -5.777009e-04
# 9   -4.640968e-03 -4.834185e-03
# 10   1.309978e-03 -3.725225e-03
# 11   2.111332e-04 -2.379671e-04
# 12  -3.225600e-03 -1.021504e-03
# 13  -2.461773e-03  3.012655e-04
# 14   1.669157e-03 -2.719042e-03
# 15  -8.562598e-03 -1.644018e-02
# 16  -3.284743e-03 -1.697089e-03
# 17  -5.151098e-04  3.704126e-05
# 18  -1.260693e-05  1.028936e-05
# 19  -5.057780e-03 -5.349617e-03
# 20  -2.111087e-03 -2.088128e-04
# 21  -1.496927e-03 -1.199037e-03
# 22  -5.283295e-05  1.299725e-05
# 23  -3.046306e-03 -5.948606e-03
# 24  -7.746117e-05  1.236234e-05
# 25  -3.348871e-03 -4.994680e-04
# 26  -4.285677e-04  1.247041e-04
# 27  -4.690595e-03 -3.916806e-04
# 28  -1.966524e-04 -2.628023e-04
# 29  -7.678563e-03 -5.907607e-03
# 30  -3.292090e-03 -2.534721e-03
# ⋮   ⋮             ⋮
# 751 -6.011334e-03 -6.200061e-03
# 752  1.079659e-04 -1.762211e-03
# 753 -4.473308e-03 -3.428045e-03
# 754  4.850839e-05 -1.552350e-02
# 755  5.918415e-03 -3.649055e-03
# 756  9.155883e-04  2.685187e-05
# 757 -1.947376e-03 -3.604045e-03
# 758  1.740133e-04  1.640020e-04
# 759  9.569201e-04 -1.687923e-02
# 760 -4.715744e-04 -1.140594e-03
# 761  2.898643e-04  1.828766e-05
# 762  9.001082e-05 -2.264480e-04
# 763 -3.926041e-04 -1.098413e-02
# 764 -6.402425e-06  2.273574e-06
# 765 -3.885005e-03 -3.475956e-03
# 766 -5.219609e-03 -4.697859e-03
# 767 -7.233916e-03 -6.898571e-03
# 768 -2.997267e-04 -4.943089e-04
# 769 -1.763381e-03 -7.561355e-03
# 770 -4.225977e-05 -2.193509e-04
# 771 -8.356668e-04 -1.868983e-04
# 772 -5.841429e-03 -5.305110e-03
# 773  1.927392e-03 -3.337690e-03
# 774 -6.764141e-03 -3.408187e-03
# 775 -2.308658e-03 -8.810224e-04
# 776 -5.566597e-05  1.696700e-05
# 777 -3.583168e-03 -5.871369e-04
# 778 -3.366270e-03 -1.817342e-03
# 779 -2.961064e-03 -2.274588e-03
# 780 -4.148237e-03 -3.795508e-03

# %%
par(pty="s")
plot(lgbb2$mach, lgbb2$alpha, xlab="mach", ylab="alpha", pch=18, cex=0.5)
# Out:
# plot without title

# %%
apply(lgbb2[,2:4], 2, function(x) { length(unique(x)) })
# Out:
#  mach alpha  beta
#   110    36     9

# %%
par(pty="s")
a2 <- which(lgbb2$alpha == 1)
a2 <- a2[order(lgbb2$mach[a2])]
plot(lgbb2$mach[a2], lgbb2$lift[a2], type="l", xlab="mach", ylab="lift", lwd=2)
text(4, 0.15, paste("length(a2) =", length(a2)))
# Out:
# plot without title

# %%
# lgbb2 %>% 
#   filter(alpha == 1) %>% 
#   arrange(mach) %>% 
#   ggplot(aes(mach, lift, color = beta)) +
#   geom_point() +
#   geom_line() +
#   theme(aspect.ratio = 1)

# %%
load("data/lgbb/lgbb_fill.Rdata")
lgbb.fill
# Out:
#       mach alpha beta lift       drag       pitch         side
# 1     0.20 -5    0    -0.1045931 0.05329781 -0.0303296504  9.251485e-04
# 2     0.25 -5    0    -0.1074439 0.04583683 -0.0294788893  9.540935e-04
# 3     0.30 -5    0    -0.1101905 0.04046482 -0.0288654697  9.867133e-04
# 4     0.35 -5    0    -0.1125995 0.03667648 -0.0284924326  9.619488e-04
# 5     0.40 -5    0    -0.1147496 0.03381879 -0.0282899668  9.026150e-04
# 6     0.45 -5    0    -0.1170762 0.03160980 -0.0281228514  8.804300e-04
# 7     0.50 -5    0    -0.1196389 0.02988756 -0.0280288750  8.503585e-04
# 8     0.55 -5    0    -0.1221008 0.02855839 -0.0279102049  7.876423e-04
# 9     0.60 -5    0    -0.1246332 0.02745525 -0.0277740066  7.523836e-04
# 10    0.65 -5    0    -0.1275252 0.02666818 -0.0278394825  7.768039e-04
# 11    0.70 -5    0    -0.1307484 0.02606526 -0.0280880073  7.194323e-04
# 12    0.75 -5    0    -0.1336937 0.02579363 -0.0287044604  6.559737e-04
# 13    0.80 -5    0    -0.1350411 0.02644927 -0.0299249858  5.039375e-04
# 14    0.85 -5    0    -0.1410690 0.03187132 -0.0317166693  4.295749e-04
# 15    0.90 -5    0    -0.1689334 0.05147157 -0.0291682489  5.048110e-04
# 16    0.95 -5    0    -0.2771987 0.08322666  0.0024768486  5.526305e-04
# 17    1.00 -5    0    -0.2822073 0.09822279  0.0065147770  4.712495e-04
# 18    1.05 -5    0    -0.2692547 0.09998954  0.0050370309  3.934188e-04
# 19    1.10 -5    0    -0.2600062 0.10134305  0.0032390417  3.012822e-04
# 20    1.15 -5    0    -0.2586709 0.10119497  0.0052434155  2.304805e-04
# 21    1.20 -5    0    -0.2575083 0.10169297  0.0064176180  1.859359e-04
# 22    1.25 -5    0    -0.2418499 0.10084600  0.0029516834  1.444900e-04
# 23    1.30 -5    0    -0.2320566 0.09981873  0.0016419193  1.181677e-04
# 24    1.35 -5    0    -0.2245916 0.09866271  0.0005850434  8.405326e-05
# 25    1.40 -5    0    -0.2178895 0.09746004 -0.0001540585  7.572921e-05
# 26    1.45 -5    0    -0.2115032 0.09617513 -0.0008505493  8.480254e-05
# 27    1.50 -5    0    -0.2057130 0.09489520 -0.0014210552  6.168373e-05
# 28    1.55 -5    0    -0.2009835 0.09359642 -0.0020704533  1.529576e-05
# 29    1.60 -5    0    -0.1967557 0.09234180 -0.0024522059  2.372915e-05
# 30    1.65 -5    0    -0.1929320 0.09119058 -0.0026756710 -5.807434e-06
# 22    -6.129714e-05 9.800771e-05
# 23    -6.033556e-05 9.515208e-05
# 24    -5.104303e-05 6.734309e-05
# 25    -4.786149e-05 5.123384e-05
# 26    -4.164182e-05 4.293569e-05
# 27    -3.395671e-05 3.704786e-05
# 28    -1.670734e-05 3.128441e-05
# 29    -4.426535e-06 2.797837e-05
# 30     6.679547e-06 2.635508e-05
# ⋮     ⋮             ⋮
# 37879 -0.007758261  -0.007347440
# 37880 -0.007769458  -0.007336092
# 37881 -0.007777336  -0.007327085
# 37882 -0.007781944  -0.007317658
# 37883 -0.007786128  -0.007307055
# 37884 -0.007785553  -0.007299295
# 37885 -0.007783784  -0.007292995
# 37886 -0.007782146  -0.007283999
# 37887 -0.007776896  -0.007274830
# 37888 -0.007769399  -0.007268281
# 37889 -0.007761746  -0.007257186
# 37890 -0.007751424  -0.007249617
# 37891 -0.007741041  -0.007234714
# 37892 -0.007732780  -0.007221076
# 37893 -0.007719911  -0.007201739
# 37894 -0.007710727  -0.007187299
# 37895 -0.007696662  -0.007161592
# 37896 -0.007686596  -0.007140026
# 37897 -0.007673553  -0.007114949
# 37898 -0.007663676  -0.007085515
# 37899 -0.007653335  -0.007054529
# 37900 -0.007648462  -0.007018296
# 37901 -0.007636998  -0.006987675
# 37902 -0.007629783  -0.006950879
# 37903 -0.007624429  -0.006911103
# 37904 -0.007616156  -0.006870679
# 37905 -0.007609009  -0.006829886
# 37906 -0.007602247  -0.006791791
# 37907 -0.007597784  -0.006744711
# 37908 -0.007592267  -0.006703617

# %%
lgbb.b1 <- lgbb.fill[lgbb.fill$beta == 1, ]
g <- interp(lgbb.b1$mach, lgbb.b1$alpha, lgbb.b1$lift)
par(pty="s")
image(g, col=heat.colors(128), xlab="mach [beta=1]", ylab="alpha [beta=1]")
# Out:
# Error in interp(lgbb.b1$mach, lgbb.b1$alpha, lgbb.b1$lift): could not find function "interp"
# Traceback:

# %%
par(pty="s")
plot(lgbb.b1$mach, lgbb.b1$lift, type="n", xlab="mach", ylab="lift [beta=1]")
for(ub in unique(lgbb.b1$alpha)) {
  a <- which(lgbb.b1$alpha == ub)
  a <- a[order(lgbb.b1$mach[a])]
  lines(lgbb.b1$mach[a], lgbb.b1$lift[a], type="l", lwd=2)
}
# Out:
# plot without title

# %%
crash <- read.csv("data/crash/CRASHExpt_clean.csv")
crash$BeThickness <- 21
names(crash)
nrow(crash)
# Out:
# [1] "LaserEnergy"   "GasPressure"   "AspectRatio"   "NozzleLength"
# [5] "TaperLength"   "TubeDiameter"  "Time"          "ShockLocation"
# [9] "BeThickness"
# [1] 20

# %%
ce1 <- read.csv("data/crash/RS12_SLwithUnnormalizedInputs.csv")
ce2 <- read.csv("data/crash/RS13Minor_SLwithUnnormalizedInputs.csv")
ce2$ElectronFluxLimiter <- 0.06

# %%
sfmin <- ce2$EffectiveLaserEnergy/5000
sflen <- 10
ce2.sf <- matrix(NA, nrow=sflen*nrow(ce2), ncol=ncol(ce2) + 2)
for(i in 1:sflen) {
  sfi <- sfmin + (1 - sfmin)*(i/sflen)
  ce2.sf[(i - 1)*nrow(ce2) + (1:nrow(ce2)),] <-
    cbind(as.matrix(ce2), sfi, ce2$EffectiveLaserEnergy/sfi)
}
ce2.sf <- as.data.frame(ce2.sf)
names(ce2.sf) <- c(names(ce2), "EnergyScaleFactor", "LaserEnergy")
#sum(!complete.cases(ce2.sf))

# %%
par(pty="s")
plot(ce2.sf$LaserEnergy, ce2.sf$EnergyScaleFactor, ylim=c(0.4, 1.1), 
     xlab="Laser Energy", ylab="Energy Scale Factor")
points(ce1$LaserEnergy, ce1$EnergyScaleFactor, col=2, pch=19)
legend("bottomleft", c("CE2", "CE1"), col=1:2, pch=c(21,19))
# Out:
# plot without title

# %%
u <- apply(crash, 2, function(x) { length(unique(x)) })
u
# Out:
#   LaserEnergy   GasPressure   AspectRatio  NozzleLength   TaperLength
#            13            11             1             1             1
#  TubeDiameter          Time ShockLocation   BeThickness
#             2             6            20             1

# %%
fit <- lm(ShockLocation ~ ., data=crash[, u > 1])
signif(summary(fit)$coefficients, digits = 3)
# summary(fit)
# Out:
#              Estimate  Std. Error t value Pr(>|t|)
# (Intercept)   2.51e+03 6.27e+03    0.4000 6.95e-01
# LaserEnergy  -3.97e-01 1.49e+00   -0.2660 7.94e-01
# GasPressure  -1.97e+02 8.48e+02   -0.2320 8.19e-01
# TubeDiameter -3.42e-02 4.07e-01   -0.0842 9.34e-01
# Time          1.04e+11 1.57e+10    6.6400 7.87e-06

# %%
par(pty="s")
fit.time <- lm(ShockLocation ~ Time, data=crash)
plot(crash$Time, crash$ShockLocatio, xlab="time", ylab="location")
abline(fit.time)
# Out:
# plot without title

# %%
ce1 <- ce1[,-1]
u.ce1 <- apply(ce1, 2, function(x) { length(unique(x)) })
u.ce1
# Out:
#         BeThickness         LaserEnergy         GasPressure         AspectRatio
#                  96                  96                  96                   1
#        NozzleLength         TaperLength        TubeDiameter                Time
#                   1                   1                   1                  24
# ElectronFluxLimiter   EnergyScaleFactor       ShockLocation
#                  96                  96                1723

# %%
fit.ce1 <- lm(ShockLocation ~ ., data = ce1[, u.ce1 > 1])
summary(fit.ce1)
# Out:
# Call:
# lm(formula = ShockLocation ~ ., data = ce1[, u.ce1 > 1])
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -608.71  -80.31   41.48  107.38  335.73
#
# Coefficients:
#                       Estimate Std. Error t value Pr(>|t|)
# (Intercept)         -4.601e+02  1.321e+02  -3.483 0.000503 ***
# BeThickness         -7.595e+01  2.104e+00 -36.101  < 2e-16 ***
# LaserEnergy          3.153e-01  2.149e-02  14.672  < 2e-16 ***
# GasPressure         -3.829e+02  8.129e+01  -4.710  2.6e-06 ***
# Time                 1.344e+11  4.998e+08 268.844  < 2e-16 ***
# ElectronFluxLimiter  4.126e+02  1.400e+02   2.947 0.003233 **
# EnergyScaleFactor    1.776e+03  1.214e+01 146.248  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 152.2 on 2611 degrees of freedom
# Multiple R-squared:  0.9705,	Adjusted R-squared:  0.9705
# F-statistic: 1.434e+04 on 6 and 2611 DF,  p-value: < 2.2e-16

# %%
x <- ce1$Time
y <- ce1$LaserEnergy * ce1$EnergyScaleFactor
g <- interp(x/max(x), y/max(y), ce1$ShockLocation, dupl="mean")
par(pty="s")
image(g, col=heat.colors(128), xlab="scaled time", ylab="scaled energy")
# Out:
# Error in interp(x/max(x), y/max(y), ce1$ShockLocation, dupl = "mean"): could not find function "interp"
# Traceback:
